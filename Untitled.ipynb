# %%
import scipy.io as sio
import numpy as np

# Load the .mat file
data = sio.loadmat('Salinas_corrected.mat')

# Extract the hyperspectral data
hsi_data = data['salinas_corrected']

# Check the shape of the data
print("Shape of the hyperspectral data:", hsi_data.shape)

# Display the first band as an example
import matplotlib.pyplot as plt

plt.imshow(hsi_data[:, :, 39], cmap='gray')
plt.title('First Band of Salinas Dataset')
plt.colorbar()
plt.show()
# Normalize the data to the range [0, 1]
hsi_data_normalized = hsi_data.astype(np.float32)
hsi_data_normalized = (hsi_data_normalized - np.min(hsi_data_normalized)) / (np.max(hsi_data_normalized) - np.min(hsi_data_normalized))

print(hsi_data_normalized.shape)
# Out:
# Shape of the hyperspectral data: (512, 217, 204)
# (512, 217, 204)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

def create_cnn(input_shape):
    model = models.Sequential()
    
    # First Convolutional Layer
    model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(layers.MaxPooling2D((2, 2)))
    
    # Second Convolutional Layer
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))
    
    # Flatten and Dense Layers
    model.add(layers.Flatten())
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(16, activation='softmax'))  # 16 classes
    
    return model

# Example usage:
input_shape = (hsi_data.shape[0], hsi_data.shape[1], 1)  # Adjust as needed
cnn_model = create_cnn(input_shape)
cnn_model.summary()
# Out:
# 2024-08-27 14:57:20.032439: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-08-27 14:57:20.033983: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-08-27 14:57:20.038071: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-08-27 14:57:20.052089: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...

# %%
import numpy as np
import scipy.io as sio
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Add, Multiply
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split

# Load the .mat file
data = sio.loadmat('Salinas_corrected.mat')

# Extract the hyperspectral data
salinas_data = data['salinas_corrected']

# Check the shape of the data
print("Shape of the hyperspectral data:", salinas_data.shape)
if len(salinas_data.shape) == 3:
    salinas_data = np.expand_dims(salinas_data, axis=0)  # Add a batch dimension
if salinas_data.shape[0] < 2:
    # Simulate additional samples
    num_simulated_samples = 10  # Adjust as needed
    salinas_data = np.tile(salinas_data, (num_simulated_samples, 1, 1, 1))

# Preprocess the data
def preprocess_data(data):
    # Ensure data is 4D (samples, height, width, bands)
    if len(data.shape) == 3:
        data = np.expand_dims(data, axis=0)  # Add a batch dimension if needed

    # Normalize the data
    data = (data - np.min(data)) / (np.max(data) - np.min(data))

    # Check the number of samples
    num_samples = data.shape[0]
    if num_samples <= 1:
        raise ValueError("Insufficient data samples for train-test split")

    # Create dummy labels for demonstration (replace with actual labels)
    labels = np.random.randint(0, 10, size=num_samples)

    # Split into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

    # Convert labels to one-hot encoding
    y_train = tf.keras.utils.to_categorical(y_train, num_classes=10)
    y_test = tf.keras.utils.to_categorical(y_test, num_classes=10)

    return X_train, X_test, y_train, y_test

# Define Attention Mechanism
def attention_module(x):
    # Channel Attention
    channel_att = Conv2D(filters=x.shape[-1], kernel_size=1, activation='sigmoid')(x)
    channel_att = Multiply()([x, channel_att])

    # Spatial Attention
    spatial_att = Conv2D(filters=1, kernel_size=1, activation='sigmoid')(x)
    spatial_att = Multiply()([x, spatial_att])

    return Add()([channel_att, spatial_att])

# Build the CNN model with Attention
def build_model(input_shape):
    inputs = Input(shape=input_shape)
    x = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = attention_module(x)
    x = Flatten()(x)
    x = Dense(128, activation='relu')(x)
    outputs = Dense(10, activation='softmax')(x)  # Example: 10 classes for classification

    model = Model(inputs, outputs)
    model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Define input shape (e.g., height, width, bands)
# Define input shape (height, width, bands)
# Define input shape (height, width, bands)
# This should exclude the batch dimension
  # Exclude the batch dimension
  # Exclude the batch dimension
print("Shape of the hyperspectral data:", salinas_data.shape)

X_train, X_test, y_train, y_test = preprocess_data(salinas_data)
print("Shape of the hyperspectral data:", salinas_data.shape)

input_shape = X_train.shape[1:]  
# Build and train the model
model = build_model(input_shape)


# Train the model
model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2)
model.evaluate(X_test, y_test)
# Out:
# 2024-08-27 15:15:48.038473: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-08-27 15:15:48.053829: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-08-27 15:15:48.188054: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-08-27 15:15:48.319240: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...
